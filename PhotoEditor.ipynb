# %%
from tkinter import *
from tkinter import ttk
from PIL import ImageTk, Image, ImageFilter, ImageFont, ImageDraw
import random

root = Tk()

# Создание окна
root.title("Фоторедактор")

# Установка размера
root.geometry("500x500")

#Приветствие
welcome = Label(text="Добро пожаловать в фоторедактор")
welcome.pack()

# Загрузка изображения
open_image = Image.open(input("Введите путь к файлу"))
my_img = ImageTk.PhotoImage(open_image)
my_label = Label(image=my_img)
my_label.pack()

# Функция для обработки изображения
def apply_filter(filter_name):
    # загрузка изображения в качестве объекта Pillow
    img = open_image
    
    # применение фильтра
    
    #обрезка
    if filter_name == "crop":
        print('Введите координаты правого нижнего угла и левого верхнего угла')
        img = img.crop((int(input()), int(input()), int(input()),int(input())))
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
    
    #поворот
    elif  filter_name == "rotate":
        img = img.rotate(int(input('Под каким углом хотите повернуть изображение?')))
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
    
    #отразить зеркально по горизонтали(слева направо) 
    elif filter_name == "transpose_left_right":
        img  = img.transpose(Image.Transpose.FLIP_LEFT_RIGHT)
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
     
    #отразить зеркально по вертикали(сверху вниз) 
    elif filter_name == "transpose_top_bottom":
        img = img.transpose(Image.Transpose.FLIP_TOP_BOTTOM)
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
     
    #резкость
    elif filter_name == "detail":
        img = img.filter(ImageFilter.DETAIL)
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
     
    #размытие
    elif filter_name == "blur":
        img = img.filter(ImageFilter.BLUR)
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
     
    #цветовой шум
    elif filter_name == "color_noise":
        for i in range(img.width):
            for j in range(img.height):
                r, g, b = img.getpixel((i, j))
                r += random.randint(-150, 150)
                g += random.randint(-150, 150)
                b += random.randint(-150, 150)
                img.putpixel((i, j), (r, g, b))
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
    
    #оттенки серого
    elif filter_name == "gray":
        img = img.convert('L')
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
        
    #сепия
    elif filter_name == "sepia":
        sepia = lambda r,g,b: (int(r * 0.393 + g * 0.769 + b * 0.189),
                              int(r * 0.349 + g * 0.686 + b * 0.168),
                              int(r * 0.272 + g * 0.534 + b * 0.131))
        img = img.convert('RGB')        
        img = img.point(sepia)
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
     
    #наложение текста
    elif filter_name == "text":
        font = ImageFont.load_default()
        pencil = ImageDraw.Draw(img)
        pencil.text((int(input()), int(input())), input(), font = font, fill = input, size=int(input()))
        filtered_image = img.save(input('Укажите путь для сохранения и напишите название файла'))
        
  
    # обновление изображения в окне
    my_img_filtered = ImageTk.PhotoImage(filtered_image)
    my_label.configure(image=my_img_filtered)
    my_label.image = my_img_filtered
    
    
# Создание кнопок
crop_btn = Button(root, text="Обрезка", command=lambda: apply_filter("crop"))
crop_btn.pack()

rotate_btn = Button(root, text="Поворот", command=lambda: apply_filter("rotate"))
rotate_btn.pack()

trans_l_r_btn = Button(root, text="Отразить зеркально по горизонтали(слева направо)", command=lambda: apply_filter("transpose_left_right"))
trans_l_r_btn.pack()

trans_s_b_btn = Button(root, text="Отразить зеркально по вертикали(сверху вниз)", command=lambda: apply_filter("transpose_top_bottom"))
trans_s_b_btn.pack()

detail_btn = Button(root, text="Резкость", command=lambda: apply_filter("detail"))
detail_btn.pack()

blur_btn = Button(root, text="Размытие", command=lambda: apply_filter("blur"))
blur_btn.pack()

color_noise_btn = Button(root, text="Цветовой шум", command=lambda: apply_filter("color_noise"))
color_noise_btn.pack()

gray_btn = Button(root, text="Оттенки серого", command=lambda: apply_filter("gray"))
gray_btn.pack()

sepia_btn = Button(root, text="Сепия", command=lambda: apply_filter("sepia"))
sepia_btn.pack()

text_btn = Button(root, text="Наложение текста", command=lambda: apply_filter("text"))
text_btn.pack()

ttk.Entry().pack(anchor=NW, padx=8, pady= 8)
# Запуск приложения
root.mainloop()
# Out:
# Введите путь к файлуC:\Users\Пользователь\Desktop\summer.jpg
# Укажите путь для сохранения и напишите название файлаC:\Users\Пользователь\Desktop\summ.jpg
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Anaconda\Anaconda3\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\Пользователь\AppData\Local\Temp\ipykernel_18284\2793350582.py", line 108, in <lambda>
#     trans_l_r_btn = Button(root, text="Отразить зеркально по горизонтали(слева направо)", command=lambda: apply_filter("transpose_left_right"))
#   File "C:\Users\Пользователь\AppData\Local\Temp\ipykernel_18284\2793350582.py", line 96, in apply_filter
#     my_img_filtered = ImageTk.PhotoImage(filtered_image)
#   File "C:\Anaconda\Anaconda3\lib\site-packages\PIL\ImageTk.py", line 123, in __init__
#     mode = Image.getmodebase(mode)
#   File "C:\Anaconda\Anaconda3\lib\site-packages\PIL\Image.py", line 274, in getmodebase
#     return ImageMode.getmode(mode).basemode
#   File "C:\Anaconda\Anaconda3\lib\site-packages\PIL\ImageMode.py", line 91, in getmode
#     return _modes[mode]
# KeyError: None
